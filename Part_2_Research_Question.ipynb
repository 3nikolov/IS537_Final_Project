# %%
'Setting Up Imports'
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./data/combined_data_cleaned.csv")

# %%
df
# Out:
#                 Full Name                      City  \
# 0     Abdullah  Al Qayyim             New Brunswick
# 1            Aditi Sharma                 Bangalore
# 2          Andrew  Dornon                    Austin
# 3              Anurag Dey                 Stockholm
# 4           Barth Cabouat                   Nairobi
# ...                   ...                       ...
# 2435       Nayanika Kundu                   Unknown
# 2436     Greg Gianopoulos  Asheville North Carolina
# 2437      Richard  Annilo                     Tartu
# 2438          Milan Patel                 Leicester
# 2439          Evan Murphy              Vancouver Bc
#
#                              Country                      Current Title  \
# 0                             Canada             Independent consultant
# 1                              India  Consultant (2-4 years experience)
# 2           United States Of America                              Other
# ...

# %% [markdown]
# What gaps and trends exist in career area interest and global representation across the 2 nonprofit professional networks focused on impact-driven work, and how does data quality impact these insights?

# %%
# top 10 counts of cause area interests

plt.figure(figsize=(10,10))
cause_counts = df['Cause Area Interests'].value_counts().head(10)

sns.barplot(x=cause_counts.values, y=cause_counts.index, palette = 'mako_r')
plt.title('Top 10 Cause Area Interests')
plt.xlabel('Number of People')
plt.ylabel('Cause Area')
plt.show()
# Out:
# /var/folders/vx/f0n6zqf15h9c22pcp057txxw0000gn/T/ipykernel_20803/4188679667.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cause_counts.values, y=cause_counts.index, palette = 'mako_r')

# %%
# top countries

plt.figure(figsize=(10,10))
country_counts = df['Country'].value_counts().head(10)

sns.barplot(x=country_counts.values, y=country_counts.index, palette='flare')
plt.title('Top 10 Countries')
plt.xlabel('Number of People')
plt.ylabel('Country')
plt.show()
# Out:
# /var/folders/vx/f0n6zqf15h9c22pcp057txxw0000gn/T/ipykernel_20803/1457324331.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_counts.values, y=country_counts.index, palette='flare')

# %%
# top cities

plt.figure(figsize=(10, 10))
city_counts = df['City'].value_counts().head(10)

sns.barplot(x=city_counts.values, y=city_counts.index, palette='magma_r')
plt.title('Top 10 Cities')
plt.xlabel('Number of People')
plt.ylabel('City')
plt.show()
# Out:
# /var/folders/vx/f0n6zqf15h9c22pcp057txxw0000gn/T/ipykernel_20803/1423606928.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=city_counts.values, y=city_counts.index, palette='magma_r')

# %%
# bottom cities

plt.figure(figsize=(10, 10))
city_counts = df['City'].value_counts().tail(20)

sns.barplot(x=city_counts.values, y=city_counts.index, palette='magma_r')
plt.title('Bottom 20 Cities')
plt.xlabel('Number of People')
plt.ylabel('City')
plt.show()
# Out:
# /var/folders/vx/f0n6zqf15h9c22pcp057txxw0000gn/T/ipykernel_20803/1644670737.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=city_counts.values, y=city_counts.index, palette='magma_r')

# %%
from collections import Counter

all_text = " ".join(df['Cause Area Interests'].astype(str))
words = all_text.split()
word_counts = Counter(words)
top_words = word_counts.most_common(10)

words, counts = zip(*top_words)
plt.figure(figsize=(10,10))
plt.barh(words, counts, color='red')
plt.title('Top 10 Words in Career Area Interest')
plt.xlabel('Count')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Summary of findings

# %% [markdown]
# Most people are located in the United States, followed by the UK second, and Germany third. Cities don't follow the exact same pattern but they are somewhat correlated, as London, UK is the top city, followed by 'Unknown', and then 'Berlin' third and 'New York' fourth. The top cause area interest seems to be animal welfare, followed by 'Missing Information', and then combinations of multiple options that include animal welfare, environment and sustainability, and climate change. Surprisingly given today's technological climate, AI technical research/strategy and policy is towards the bottom of the top 10 at number 9.
#
# Depending on what research question is chosen, data quality will affect those insights differently. Here, we have values of 'unknown' and 'missing information' to indicate that missing data unfortunately represents a large portion of values for cause area and city. From this we can ask questions for future directions for this dataset: if we merged the dataframes instead of concatenating them, what would this do? Would we see the same geographical over-representation of the United States, Germany and the UK? What external sources could we grab to examine the accuracy of if people's cause areas of interest are "true"? These are questions for people to build on.
